# %%
from utils.env_data_processor import create_env_data_processor
import pandas  as pd
import numpy as np
import plotly.express as px
from datetime import  datetime
from utils.data_preprocessing import (
    query_data_by_batch_time,
)

# %% [markdown]
# # 蘑菇数据环境数据处理
# 以611库房为例，获取历史物联控制数据，
# - 分析1-27天内每天温湿度、光照情况
# - 分析关键节点设备参数调控情况
# -

# %%
room_id = "611"
# 测试代码
processor = create_env_data_processor()
 # 获取特定库房的设备配置（使用缓存）
room_configs = processor._get_device_configs_cached(room_id)

            # 合并所有设备类型的配置
all_query_df = pd.concat(room_configs.values(), ignore_index=True)
start_time =datetime(2025,12,19,0,0,0)
end_time = datetime(2026,1,12,0,0,0)
               
            # 查询历史数据 - 使用与 get_env_status.py 相同的逻辑
df = all_query_df.groupby("device_alias", group_keys=False).apply(
                query_data_by_batch_time, 
                start_time, 
                end_time
            ).reset_index().sort_values("time")
            
        
            # 添加库房信息 - 从设备名称中提取库房号
df['room'] = df['device_name'].apply(lambda x: x.split('_')[-1])
            
            # 创建透视表 - 与 get_env_status.py 中的 df1 相同结构
df1 = df.pivot_table(
                index='time',
                columns=['room', 'device_name', 'point_name'],
                values='value'
            )
df1
# Out:
# 2026-01-09 17:42:54.828 | INFO     | utils.env_data_processor:__init__:31 - Environment data processor initialized successfully
# 2026-01-09 17:42:54.828 | DEBUG    | utils.env_data_processor:_get_device_configs_cached:57 - 查询设备配置: 库房 611
# 2026-01-09 17:42:54.926 | DEBUG    | utils.dataframe_utils:get_all_device_configs:92 - Found 5 devices for room 611, device_type air_cooler
# 2026-01-09 17:42:54.945 | DEBUG    | utils.dataframe_utils:get_all_device_configs:92 - Found 6 devices for room 611, device_type fresh_air_fan
# 2026-01-09 17:42:54.964 | DEBUG    | utils.dataframe_utils:get_all_device_configs:92 - Found 8 devices for room 611, device_type humidifier
# 2026-01-09 17:42:54.985 | DEBUG    | utils.dataframe_utils:get_all_device_configs:92 - Found 4 devices for room 611, device_type grow_light
# 2026-01-09 17:42:55.008 | DEBUG    | utils.dataframe_utils:get_all_device_configs:92 - Found 6 devices for room 611, device_type mushroom_info
# 2026-01-09 17:42:55.028 | DEBUG    | utils.dataframe_utils:get_all_device_configs:92 - Found 3 devices for room 611, device_type mushroom_env_status
# 2026-01-09 17:42:55.028 | DEBUG    | utils.env_data_processor:_get_device_configs_cached:63 - 缓存设备配置: 库房 611, 设备类型数量: 6

# %%
all_query_df
# Out:
#                                       remark  point_name   point_alias  \
# 0                                      冷风机开关       OnOff        status
# 1   0=风机制冷运行 1=风机制热运行 2=风机正常运行 3=风机停止 4=风机关闭     Running          mode
# 2                               温度设定(分辨率0.1)      TemSet      temp_set
# 3                               库内温度(分辨率0.1)         Tem          temp
# 4                               温差设定(分辨率0.1)  TemDiffSet  temp_diffset
# 5                新风模式 0=关闭模式\n1=自动模式\n2=手动模式       Model          mode
# 6                     新风控制方式 \n0=时控\n1=CO2控制     Control       control
# 7                                    CO2启动新风       Co2On        co2_on
# 8                                    CO2停止新风      Co2Off       co2_off
# 9                                     新风开启设定          On            on
# 10                                    新风停止设定         Off           off
# 11                                      加湿状态     Running        status
# 12                                      加湿状态     Running        status
# 13                                    加湿停止设定         Off           off
# 14                                    加湿停止设定         Off           off
# 15                                      加湿模式       Model          mode
# 16                                      加湿模式       Model          mode
# 17                                    加湿开启设定          On            on
# 18                                    加湿开启设定          On            on
# 19               补光模式 0=关闭模式\n1=自动模式\n2=手动模式       Model         model
# 20                                      补光状态     Running          mode
# 21                                  补光停止分钟设定     OffMSet      off_mset
# 22                                  补光开启分钟设定      OnMSet       on_mset
# 23                                       进库月     InMonth      in_month
# 24                                       进库日       InDay        in_day
# 25                                       进库年      InYear       in_year
# 26                                   育菇房（库号）      Number       in_time
# 27                                      进库包数       InNum        in_num
# 28                                      进库天数    InDayNum    in_day_num
# 29                               库内温度/分辨率0.1     Tatmosp   temperature
# 30                                      库内湿度     Hatmosp      humidity
# 31                                     库内CO2         Co2           co2
#
#                                                  enum      device_name  \
# 0                                                None     TD1_Q1MDCH01
# 1   {'0': '制冷运行', '1': '制热运行', '2': '正常运行', '3': '...     TD1_Q1MDCH01
# 2                                                None     TD1_Q1MDCH01
# 3                                                None     TD1_Q1MDCH01
# 4                                                None     TD1_Q1MDCH01
# 5                                                 NaN     TD1_Q1MDAR01
# 6                                                 NaN     TD1_Q1MDAR01
# 7                                                 NaN     TD1_Q1MDAR01
# 8                                                 NaN     TD1_Q1MDAR01
# 9                                                 NaN     TD1_Q1MDAR01
# 10                                                NaN     TD1_Q1MDAR01
# 11                                                NaN    TD1_Q1MDHUM01
# 12                                                NaN    TD1_Q1MDHUM02
# 13                                                NaN    TD1_Q1MDHUM01
# 14                                                NaN    TD1_Q1MDHUM02
# 15                                                NaN    TD1_Q1MDHUM01
# 16                                                NaN    TD1_Q1MDHUM02
# 17                                                NaN    TD1_Q1MDHUM01
# 18                                                NaN    TD1_Q1MDHUM02
# 19                                                NaN  TD1_Q1MDLIGHT01
# 20                                                NaN  TD1_Q1MDLIGHT01
# 21                                                NaN  TD1_Q1MDLIGHT01
# 22                                                NaN  TD1_Q1MDLIGHT01
# 23                                                NaN   TD1_Q1MDINFO01
# 24                                                NaN   TD1_Q1MDINFO01
# 25                                                NaN   TD1_Q1MDINFO01
# 26                                                NaN   TD1_Q1MDINFO01
# 27                                                NaN   TD1_Q1MDINFO01
# 28                                                NaN   TD1_Q1MDINFO01
# 29                                                NaN     TD1_Q1MDTM01
# 30                                                NaN     TD1_Q1MDTM01
# 31                                                NaN     TD1_Q1MDTM01
#
#             device_alias
# 0         air_cooler_611
# 1         air_cooler_611
# 2         air_cooler_611
# 3         air_cooler_611
# 4         air_cooler_611
# 5      fresh_air_fan_611
# 6      fresh_air_fan_611
# 7      fresh_air_fan_611
# 8      fresh_air_fan_611
# 9      fresh_air_fan_611
# 10     fresh_air_fan_611
# 11   left_humidifier_611
# 12  right_humidifier_611
# 13   left_humidifier_611
# 14  right_humidifier_611
# 15   left_humidifier_611
# 16  right_humidifier_611
# 17   left_humidifier_611
# 18  right_humidifier_611
# 19        grow_light_611
# 20        grow_light_611
# 21        grow_light_611
# 22        grow_light_611
# 23     mushroom_info_611
# 24     mushroom_info_611
# 25     mushroom_info_611
# 26     mushroom_info_611
# 27     mushroom_info_611
# 28     mushroom_info_611
# 29        env_status_611
# 30        env_status_611
# 31        env_status_611

# %%
df1.to_csv('../data/611_20251219-20260106.csv')

# %%
df1=pd.read_csv('../data/611_20251219-20260106.csv',header=[0,1,2],index_col=0)
df1
# Out:
# room                           611                                     \
# device_name         air_cooler_611
# point_name                    mode status  temp temp_diffset temp_set
# time
# 2025-12-19 00:00:00            3.0    1.0  18.5          1.0     19.0
# 2025-12-19 00:01:00            3.0    1.0  18.6          1.0     19.0
# 2025-12-19 00:02:00            3.0    1.0  18.8          1.0     19.0
# 2025-12-19 00:03:00            3.0    1.0  18.9          1.0     19.0
# 2025-12-19 00:04:00            2.0    1.0  19.0          1.0     19.0
# ...                            ...    ...   ...          ...      ...
# 2026-01-09 10:09:00            3.0    1.0  18.6          1.0     18.5
# 2026-01-09 10:10:00            3.0    1.0  18.5          1.0     18.5
# 2026-01-09 10:11:00            3.0    1.0  18.6          1.0     18.5
# 2026-01-09 10:12:00            3.0    1.0  18.6          1.0     18.5
# 2026-01-09 10:13:00            3.0    1.0  18.6          1.0     18.5
#
# room                                                                       \
# device_name         env_status_611                      fresh_air_fan_611
# point_name                     co2 humidity temperature           co2_off
# time
# 2025-12-19 00:00:00            NaN      NaN         NaN            2500.0
# 2025-12-19 00:01:00            NaN      NaN         NaN            2500.0
# 2025-12-19 00:02:00            NaN      NaN         NaN            2500.0
# 2025-12-19 00:03:00            NaN      NaN         NaN            2500.0
# 2025-12-19 00:04:00            NaN      NaN         NaN            2500.0
# ...                            ...      ...         ...               ...
# 2026-01-09 10:09:00         1914.0    91.96        18.5            2500.0
# 2026-01-09 10:10:00         1935.0    91.98        18.6            2500.0
# 2026-01-09 10:11:00         1949.0    91.96        18.6            2500.0
# 2026-01-09 10:12:00         1965.0    91.99        18.6            2500.0
# 2026-01-09 10:13:00            NaN      NaN         NaN               NaN
#
# room                         ...                                        \
# device_name                  ... mushroom_info_611
# point_name           co2_on  ...            in_day in_day_num in_month
# time                         ...
# 2025-12-19 00:00:00  3000.0  ...              27.0       23.0     11.0
# 2025-12-19 00:01:00  3000.0  ...              27.0       23.0     11.0
# 2025-12-19 00:02:00  3000.0  ...              27.0       23.0     11.0
# 2025-12-19 00:03:00  3000.0  ...              27.0       23.0     11.0
# 2025-12-19 00:04:00  3000.0  ...              27.0       23.0     11.0
# ...                     ...  ...               ...        ...      ...
# 2026-01-09 10:09:00  3000.0  ...              24.0       17.0     12.0
# 2026-01-09 10:10:00  3000.0  ...              24.0       17.0     12.0
# 2026-01-09 10:11:00  3000.0  ...              24.0       17.0     12.0
# 2026-01-09 10:12:00  3000.0  ...              24.0       17.0     12.0
# 2026-01-09 10:13:00     NaN  ...               NaN        NaN      NaN
#
# room                                                                        \
# device_name                                 right_humidifier_611
# point_name           in_num in_time in_year                 mode  off   on
# time
# 2025-12-19 00:00:00  9792.0   611.0  2025.0                  1.0  8.0  5.0
# 2025-12-19 00:01:00  9792.0   611.0  2025.0                  1.0  8.0  5.0
# 2025-12-19 00:02:00  9792.0   611.0  2025.0                  1.0  8.0  5.0
# 2025-12-19 00:03:00  9792.0   611.0  2025.0                  1.0  8.0  5.0
# 2025-12-19 00:04:00  9792.0   611.0  2025.0                  1.0  8.0  5.0
# ...                     ...     ...     ...                  ...  ...  ...
# 2026-01-09 10:09:00  9792.0   611.0  2025.0                  1.0  8.0  6.0
# 2026-01-09 10:10:00  9792.0   611.0  2025.0                  1.0  8.0  6.0
# 2026-01-09 10:11:00  9792.0   611.0  2025.0                  1.0  8.0  6.0
# 2026-01-09 10:12:00  9792.0   611.0  2025.0                  1.0  8.0  6.0
# 2026-01-09 10:13:00     NaN     NaN     NaN                  NaN  NaN  NaN
#
# room
# device_name
# point_name          status
# time
# 2025-12-19 00:00:00    2.0
# 2025-12-19 00:01:00    2.0
# 2025-12-19 00:02:00    2.0
# 2025-12-19 00:03:00    2.0
# 2025-12-19 00:04:00    0.0
# ...                    ...
# 2026-01-09 10:09:00    2.0
# 2026-01-09 10:10:00    2.0
# 2026-01-09 10:11:00    2.0
# 2026-01-09 10:12:00    2.0
# 2026-01-09 10:13:00    NaN
#
# [30766 rows x 32 columns]

# %% [markdown]
# # 数据预处理
# 由于每个库房单独进行处理，因此列上room信息可以去掉。方便取数

# %%
df1.columns=df1.columns.droplevel(0)
df1.index = pd.to_datetime(df1.index)

# ==============================
# Step 1: Create batch_date from in_year, in_month, in_day
# ==============================
# Define the exact column tuples
in_year_col = (f'mushroom_info_{room_id}', 'in_year')
in_month_col = (f'mushroom_info_{room_id}', 'in_month')
in_day_col = (f'mushroom_info_{room_id}', 'in_day')
# Combine into datetime — this works even with MultiIndex columns!
# pd.to_datetime can accept dict-like with Series values
df1[(f'mushroom_info_{room_id}', 'batch_date')] = pd.to_datetime({
    'year': df1[in_year_col],
    'month': df1[in_month_col],
    'day': df1[in_day_col]
}, errors='coerce')  # 'coerce' turns invalid dates to NaT
df1
# Out:
# device_name         air_cooler_611                                     \
# point_name                    mode status  temp temp_diffset temp_set
# time
# 2025-12-19 00:00:00            3.0    1.0  18.5          1.0     19.0
# 2025-12-19 00:01:00            3.0    1.0  18.6          1.0     19.0
# 2025-12-19 00:02:00            3.0    1.0  18.8          1.0     19.0
# 2025-12-19 00:03:00            3.0    1.0  18.9          1.0     19.0
# 2025-12-19 00:04:00            2.0    1.0  19.0          1.0     19.0
# ...                            ...    ...   ...          ...      ...
# 2026-01-09 10:09:00            3.0    1.0  18.6          1.0     18.5
# 2026-01-09 10:10:00            3.0    1.0  18.5          1.0     18.5
# 2026-01-09 10:11:00            3.0    1.0  18.6          1.0     18.5
# 2026-01-09 10:12:00            3.0    1.0  18.6          1.0     18.5
# 2026-01-09 10:13:00            3.0    1.0  18.6          1.0     18.5
#
# device_name         env_status_611                      fresh_air_fan_611  \
# point_name                     co2 humidity temperature           co2_off
# time
# 2025-12-19 00:00:00            NaN      NaN         NaN            2500.0
# 2025-12-19 00:01:00            NaN      NaN         NaN            2500.0
# 2025-12-19 00:02:00            NaN      NaN         NaN            2500.0
# 2025-12-19 00:03:00            NaN      NaN         NaN            2500.0
# 2025-12-19 00:04:00            NaN      NaN         NaN            2500.0
# ...                            ...      ...         ...               ...
# 2026-01-09 10:09:00         1914.0    91.96        18.5            2500.0
# 2026-01-09 10:10:00         1935.0    91.98        18.6            2500.0
# 2026-01-09 10:11:00         1949.0    91.96        18.6            2500.0
# 2026-01-09 10:12:00         1965.0    91.99        18.6            2500.0
# 2026-01-09 10:13:00            NaN      NaN         NaN               NaN
#
# device_name                  ... mushroom_info_611                      \
# point_name           co2_on  ...            in_day in_day_num in_month
# time                         ...
# 2025-12-19 00:00:00  3000.0  ...              27.0       23.0     11.0
# 2025-12-19 00:01:00  3000.0  ...              27.0       23.0     11.0
# 2025-12-19 00:02:00  3000.0  ...              27.0       23.0     11.0
# 2025-12-19 00:03:00  3000.0  ...              27.0       23.0     11.0
# 2025-12-19 00:04:00  3000.0  ...              27.0       23.0     11.0
# ...                     ...  ...               ...        ...      ...
# 2026-01-09 10:09:00  3000.0  ...              24.0       17.0     12.0
# 2026-01-09 10:10:00  3000.0  ...              24.0       17.0     12.0
# 2026-01-09 10:11:00  3000.0  ...              24.0       17.0     12.0
# 2026-01-09 10:12:00  3000.0  ...              24.0       17.0     12.0
# 2026-01-09 10:13:00     NaN  ...               NaN        NaN      NaN
#
# device_name                                 right_humidifier_611            \
# point_name           in_num in_time in_year                 mode  off   on
# time
# 2025-12-19 00:00:00  9792.0   611.0  2025.0                  1.0  8.0  5.0
# 2025-12-19 00:01:00  9792.0   611.0  2025.0                  1.0  8.0  5.0
# 2025-12-19 00:02:00  9792.0   611.0  2025.0                  1.0  8.0  5.0
# 2025-12-19 00:03:00  9792.0   611.0  2025.0                  1.0  8.0  5.0
# 2025-12-19 00:04:00  9792.0   611.0  2025.0                  1.0  8.0  5.0
# ...                     ...     ...     ...                  ...  ...  ...
# 2026-01-09 10:09:00  9792.0   611.0  2025.0                  1.0  8.0  6.0
# 2026-01-09 10:10:00  9792.0   611.0  2025.0                  1.0  8.0  6.0
# 2026-01-09 10:11:00  9792.0   611.0  2025.0                  1.0  8.0  6.0
# 2026-01-09 10:12:00  9792.0   611.0  2025.0                  1.0  8.0  6.0
# 2026-01-09 10:13:00     NaN     NaN     NaN                  NaN  NaN  NaN
#
# device_name
# point_name          status
# time
# 2025-12-19 00:00:00    2.0
# 2025-12-19 00:01:00    2.0
# 2025-12-19 00:02:00    2.0
# 2025-12-19 00:03:00    2.0
# 2025-12-19 00:04:00    0.0
# ...                    ...
# 2026-01-09 10:09:00    2.0
# 2026-01-09 10:10:00    2.0
# 2026-01-09 10:11:00    2.0
# 2026-01-09 10:12:00    2.0
# 2026-01-09 10:13:00    NaN
#
# [30766 rows x 32 columns]

# %%
target_columns = {
    'Temperature': ('env_status_611', 'temperature'),
    'Humidity': ('env_status_611', 'humidity'),
    'CO2': ('env_status_611', 'co2')
}

cols_light_on = ('grow_light_611', 'on_mset')
cols_light_off = ('grow_light_611', 'off_mset')

df_viz = df1.copy()
df_viz['Date'] = df_viz.index.date

# Light hours calculation
light_daily = df_viz[[cols_light_on, cols_light_off]].resample('D').mean()
on_m = light_daily[cols_light_on].fillna(0)
off_m = light_daily[cols_light_off].fillna(0)
total_cycle = on_m + off_m
light_daily['light_hours'] = np.where(total_cycle > 0, (on_m / total_cycle) * 24, 0)

# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.express as px

# Ensure index is datetime (should already be)
df1.index = pd.to_datetime(df1.index)

# ==============================
# Step 1: Create batch_date from in_year, in_month, in_day
# ==============================
# Define the exact column tuples
in_year_col = ('mushroom_info_611', 'in_year')
in_month_col = ('mushroom_info_611', 'in_month')
in_day_col = ('mushroom_info_611', 'in_day')

# Extract and clean
years = df1[in_year_col]
months = df1[in_month_col]
days = df1[in_day_col]

# Combine into datetime — this works even with MultiIndex columns!
# pd.to_datetime can accept dict-like with Series values
df1[('mushroom_info_611', 'batch_date')] = pd.to_datetime({
    'year': years,
    'month': months,
    'day': days
}, errors='coerce')  # 'coerce' turns invalid dates to NaT

# ==============================
# Step 2: Prepare visualization data
# ==============================
target_columns = {
    'Temperature': ('env_status_611', 'temperature'),
    'Humidity': ('env_status_611', 'humidity'),
    'CO2': ('env_status_611', 'co2')
}

cols_light_on = ('grow_light_611', 'on_mset')
cols_light_off = ('grow_light_611', 'off_mset')

df_viz = df1.copy()
df_viz['Date'] = df_viz.index.date

# Light hours calculation
light_daily = df_viz[[cols_light_on, cols_light_off]].resample('D').mean()
on_m = light_daily[cols_light_on].fillna(0)
off_m = light_daily[cols_light_off].fillna(0)
total_cycle = on_m + off_m
light_daily['light_hours'] = np.where(total_cycle > 0, (on_m / total_cycle) * 24, 0)

# ==============================
# Step 3: Create subplots
# ==============================
fig = make_subplots(
    rows=4, cols=1,
    shared_xaxes=True,
    vertical_spacing=0.06,
    subplot_titles=(
        'Daily Temperature Distribution (Violin)', 
        'Daily Humidity Distribution (Violin)', 
        'Daily CO2 Distribution (Violin)',
        'Daily Light Duration (Based on Settings)'
    ),
    row_heights=[0.25, 0.25, 0.25, 0.25]
)

colors_env = {
    'Temperature': {'violin': '#3366CC', 'fill': 'rgba(51, 102, 204, 0.2)'},
    'Humidity': {'violin': '#00CC96', 'fill': 'rgba(0, 204, 150, 0.2)'},
    'CO2': {'violin': '#9467BD', 'fill': 'rgba(148, 103, 189, 0.2)'}
}

for i, (label, col) in enumerate(target_columns.items()):
    row_num = i + 1
    c = colors_env[label]
    fig.add_trace(
        go.Violin(
            x=df_viz['Date'],
            y=df_viz[col],
            name=label,
            legendgroup=label,
            showlegend=True,
            line_color=c['violin'],
            fillcolor=c['fill'],
            hoverinfo='y',
            scalemode='width',
            points='outliers',
            box_visible=True,
            meanline_visible=True
        ),
        row=row_num, col=1
    )

fig.add_trace(
    go.Bar(
        x=light_daily.index,
        y=light_daily['light_hours'],
        name='Light Hours (Est.)',
        marker_color='#FECB52',
        hovertemplate='%{x|%Y-%m-%d}<br>Duration: %{y:.1f} hrs<extra></extra>'
    ),
    row=4, col=1
)
# ==============================
# Step 3.5: Add median trend lines for each environment variable
# ==============================
# Resample to daily median
daily_median = df_viz.groupby('Date').agg({
    target_columns['Temperature']: 'median',
    target_columns['Humidity']: 'median',
    target_columns['CO2']: 'median'
}).reset_index()

# Convert 'Date' back to datetime for plotting (Plotly prefers datetime on x-axis)
daily_median['Date_dt'] = pd.to_datetime(daily_median['Date'])

# Define line colors (same as violin outline for consistency)
line_colors = {
    'Temperature': '#3366CC',
    'Humidity': '#00CC96',
    'CO2': '#9467BD'
}

# Add median lines to each subplot
for i, (label, col) in enumerate(target_columns.items()):
    row_num = i + 1
    y_vals = daily_median[col]
    x_vals = daily_median['Date_dt']
    
    # Only plot if there's at least one non-NaN value
    if y_vals.notna().any():
        fig.add_trace(
            go.Scatter(
                x=x_vals,
                y=y_vals,
                mode='lines+markers',
                name=f"{label} Median",
                legendgroup=label,
                showlegend=True,
                line=dict(color=line_colors[label], width=2.5),
                marker=dict(size=4, symbol='circle'),
                hovertemplate='%{x|%Y-%m-%d}<br>Median: %{y:.2f}<extra></extra>'
            ),
            row=row_num, col=1
        )

# ==============================
# Step 4: Add colored bands per mushroom batch
# ==============================
batch_date_col = ('mushroom_info_611', 'batch_date')
in_day_num_col = ('mushroom_info_611', 'in_day_num')

batch_series = df1[batch_date_col].dropna()
if batch_series.empty:
    print("Warning: No valid batch dates found.")
else:
    # Sort unique batch dates using numpy, then ensure Timestamp type
    unique_batches = pd.to_datetime(np.sort(batch_series.unique()))

    color_palette = px.colors.qualitative.Plotly
    for i, batch_dt in enumerate(unique_batches):
        mask = df1[batch_date_col] == batch_dt
        if mask.any():
            x0 = df1.index[mask].min()
            x1 = df1.index[mask].max()
            color = color_palette[i % len(color_palette)]
            
            # Get representative in_day_num for this batch (first non-NaN)
            day_nums = df1.loc[mask, in_day_num_col].dropna()
            day_num = int(day_nums.iloc[0]) if not day_nums.empty else "N/A"
            
            label = f"Batch {batch_dt.strftime('%Y-%m-%d')} (Day {day_num})"
            
            fig.add_vrect(
                x0=x0,
                x1=x1,
                fillcolor=color,
                opacity=0.12,
                layer='below',
                line_width=0,
                annotation_text=label,
                annotation_position="top left",
                annotation_font_size=10,
                annotation_font_color=color,
                annotation_showarrow=False
            )
# ==============================
# Step 5: Highlight growth phase using ONLY in_day_num (1-27 = growth)
# ==============================
# ==============================
# Step: Add growth phase background based solely on in_day_num
# ==============================
in_day_num_col = ('mushroom_info_611', 'in_day_num')

# Create phase mask: 1–27 → growth, else → non_growth
is_growth = df_viz[in_day_num_col].between(1, 27, inclusive='both')
df_viz['phase'] = np.where(is_growth, 'growth', 'non_growth')

# Group contiguous segments
df_viz['phase_group'] = (df_viz['phase'] != df_viz['phase'].shift()).cumsum()

# Generate continuous intervals
for (phase, _), group in df_viz.groupby(['phase', 'phase_group']):
    if group.empty:
        continue
    x0, x1 = group.index.min(), group.index.max()
    color = '#E6F7E6' if phase == 'growth' else '#FAFAFA'
    opacity = 0.25 if phase == 'growth' else 0.08
    fig.add_vrect(
        x0=x0, x1=x1,
        fillcolor=color,
        opacity=opacity,
        layer='below',
        line_width=0
        # ⚠️ No annotation_text → avoids "new text" clutter
    )
fig.update_layout(
    height=1200,
    title_text="Room 611 Daily Environment Statistics with Mushroom Batch Highlighting",
    hovermode="x unified",
    template="plotly_white",
    showlegend=True
)

fig.update_yaxes(title_text="Temperature (°C)", row=1, col=1)
fig.update_yaxes(title_text="Humidity (%)", row=2, col=1)
fig.update_yaxes(title_text="CO2 (ppm)", row=3, col=1)
fig.update_yaxes(title_text="Hours (h)", row=4, col=1)
fig.update_xaxes(title_text="Date", tickformat="%m-%d", row=4, col=1)

fig.show()

# %%
df_viz
# Out:
# device_name         air_cooler_611                                     \
# point_name                    mode status  temp temp_diffset temp_set
# time
# 2025-12-19 00:00:00            3.0    1.0  18.5          1.0     19.0
# 2025-12-19 00:01:00            3.0    1.0  18.6          1.0     19.0
# 2025-12-19 00:02:00            3.0    1.0  18.8          1.0     19.0
# 2025-12-19 00:03:00            3.0    1.0  18.9          1.0     19.0
# 2025-12-19 00:04:00            2.0    1.0  19.0          1.0     19.0
# ...                            ...    ...   ...          ...      ...
# 2026-01-09 10:09:00            3.0    1.0  18.6          1.0     18.5
# 2026-01-09 10:10:00            3.0    1.0  18.5          1.0     18.5
# 2026-01-09 10:11:00            3.0    1.0  18.6          1.0     18.5
# 2026-01-09 10:12:00            3.0    1.0  18.6          1.0     18.5
# 2026-01-09 10:13:00            3.0    1.0  18.6          1.0     18.5
#
# device_name         env_status_611                      fresh_air_fan_611  \
# point_name                     co2 humidity temperature           co2_off
# time
# 2025-12-19 00:00:00            NaN      NaN         NaN            2500.0
# 2025-12-19 00:01:00            NaN      NaN         NaN            2500.0
# 2025-12-19 00:02:00            NaN      NaN         NaN            2500.0
# 2025-12-19 00:03:00            NaN      NaN         NaN            2500.0
# 2025-12-19 00:04:00            NaN      NaN         NaN            2500.0
# ...                            ...      ...         ...               ...
# 2026-01-09 10:09:00         1914.0    91.96        18.5            2500.0
# 2026-01-09 10:10:00         1935.0    91.98        18.6            2500.0
# 2026-01-09 10:11:00         1949.0    91.96        18.6            2500.0
# 2026-01-09 10:12:00         1965.0    91.99        18.6            2500.0
# 2026-01-09 10:13:00            NaN      NaN         NaN               NaN
#
# device_name                  ... mushroom_info_611          \
# point_name           co2_on  ...           in_time in_year
# time                         ...
# 2025-12-19 00:00:00  3000.0  ...             611.0  2025.0
# 2025-12-19 00:01:00  3000.0  ...             611.0  2025.0
# 2025-12-19 00:02:00  3000.0  ...             611.0  2025.0
# 2025-12-19 00:03:00  3000.0  ...             611.0  2025.0
# 2025-12-19 00:04:00  3000.0  ...             611.0  2025.0
# ...                     ...  ...               ...     ...
# 2026-01-09 10:09:00  3000.0  ...             611.0  2025.0
# 2026-01-09 10:10:00  3000.0  ...             611.0  2025.0
# 2026-01-09 10:11:00  3000.0  ...             611.0  2025.0
# 2026-01-09 10:12:00  3000.0  ...             611.0  2025.0
# 2026-01-09 10:13:00     NaN  ...               NaN     NaN
#
# device_name         right_humidifier_611                  mushroom_info_611  \
# point_name                          mode  off   on status        batch_date
# time
# 2025-12-19 00:00:00                  1.0  8.0  5.0    2.0        2025-11-27
# 2025-12-19 00:01:00                  1.0  8.0  5.0    2.0        2025-11-27
# 2025-12-19 00:02:00                  1.0  8.0  5.0    2.0        2025-11-27
# 2025-12-19 00:03:00                  1.0  8.0  5.0    2.0        2025-11-27
# 2025-12-19 00:04:00                  1.0  8.0  5.0    0.0        2025-11-27
# ...                                  ...  ...  ...    ...               ...
# 2026-01-09 10:09:00                  1.0  8.0  6.0    2.0        2025-12-24
# 2026-01-09 10:10:00                  1.0  8.0  6.0    2.0        2025-12-24
# 2026-01-09 10:11:00                  1.0  8.0  6.0    2.0        2025-12-24
# 2026-01-09 10:12:00                  1.0  8.0  6.0    2.0        2025-12-24
# 2026-01-09 10:13:00                  NaN  NaN  NaN    NaN               NaT
#
# device_name                Date       phase phase_group
# point_name
# time
# 2025-12-19 00:00:00  2025-12-19      growth           1
# 2025-12-19 00:01:00  2025-12-19      growth           1
# 2025-12-19 00:02:00  2025-12-19      growth           1
# 2025-12-19 00:03:00  2025-12-19      growth           1
# 2025-12-19 00:04:00  2025-12-19      growth           1
# ...                         ...         ...         ...
# 2026-01-09 10:09:00  2026-01-09      growth          13
# 2026-01-09 10:10:00  2026-01-09      growth          13
# 2026-01-09 10:11:00  2026-01-09      growth          13
# 2026-01-09 10:12:00  2026-01-09      growth          13
# 2026-01-09 10:13:00  2026-01-09  non_growth          14
#
# [30766 rows x 36 columns]

# %%
# 使用封装好的可视化模块进行多房间对比分析（代码已移入 `src/utils/visualization.py`）
from datetime import datetime
from utils.visualization import analyze_and_plot_rooms

rooms = ["607", "608", "611", "612"]
start_time = datetime(2025, 12, 19, 0, 0, 0)
start_time = datetime(2026, 1, 6, 0, 0, 0)
end_time = datetime(2026, 1, 10, 0, 0, 0)

# processor 在上方 cell 已创建为 `processor`，下面按房间逐个处理并打印诊断（verbose=True）
figs = analyze_and_plot_rooms(rooms, start_time, end_time, processor=processor, return_figs=True, verbose=True)

# 简要展示结果（在 notebook 中会渲染每个 figure）
for r, f in (figs or {}).items():
    print(f'Room {r} figure: ', type(f))
    try:
        f.show()
    except Exception:
        pass
# Out:
# 2026-01-09 15:53:22.129 | INFO     | global_const.global_const:<module>:36 - [9.9.1] 已加载配置文件目录：str(BASE_DIR / /mnt/source_data/项目/蘑菇/mushroom_solution/src/configs)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 11
#       8 end_time = datetime(2026, 1, 10, 0, 0, 0)
#      10 # processor 在上方 cell 已创建为 `processor`，下面按房间逐个处理并打印诊断（verbose=True）
# ---> 11 figs = analyze_and_plot_rooms(rooms, start_time, end_time, processor=processor, return_figs=True, verbose=True)
#      13 # 简要展示结果（在 notebook 中会渲染每个 figure）
#      14 for r, f in (figs or {}).items():
#
# NameError: name 'processor' is not defined
